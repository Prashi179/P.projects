# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Creating dataframe, using head to see if it worked
df=pd.read_csv("Instagram-Data.csv")
df
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
df.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#    Followers Audience Country  Authentic engagement  Engagement avg  Scraped
# 0  400100000            India               7800000         9500000  50:24.8
# 1  308800000    United States               6200000        10100000  50:24.8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   int64
#  7   Audience Country      993 non-null    object
#  8   Authentic engagement  1000 non-null   int64
#  9   Engagement avg        1000 non-null   int64
#  10  Scraped               1000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#               Rank     Followers  Authentic engagement  Engagement avg
# count  1000.000000  1.000000e+03          1.000000e+03    1.000000e+03
# mean    500.500000  2.483610e+07          6.491228e+05    8.653886e+05
# std     288.819436  3.872143e+07          1.098804e+06    1.267515e+06
# min       1.000000  2.800000e+06          0.000000e+00    5.200000e+04
# 25%     250.750000  9.000000e+06          2.091000e+05    3.086000e+05
# 50%     500.500000  1.440000e+07          3.637000e+05    5.239000e+05
# 75%     750.250000  2.565000e+07          6.832500e+05    9.508000e+05
# max    1000.000000  4.696000e+08          1.340000e+07    1.340000e+07

# %%
# returning the relative frequency of audience country elements
# can see that 14% of the top 1,000 influencers have the India as their audience country

df["Audience Country"].value_counts(normalize=True).round(2)
# Out:
# Audience Country
# United States           0.28
# Brazil                  0.16
# India                   0.14
# Indonesia               0.13
# Mexico                  0.05
# Spain                   0.03
# Russia                  0.03
# Argentina               0.02
# Iran                    0.02
# United Kingdom          0.02
# Turkey                  0.02
# Italy                   0.02
# South Korea             0.01
# Colombia                0.01
# Philippines             0.01
# France                  0.01
# Egypt                   0.01
# Germany                 0.01
# Nigeria                 0.00
# Thailand                0.00
# Iraq                    0.00
# Morocco                 0.00
# Japan                   0.00
# Saudi Arabia            0.00
# Kazakhstan              0.00
# Syria                   0.00
# China                   0.00
# Algeria                 0.00
# United Arab Emirates    0.00
# Poland                  0.00
# Chile                   0.00
# ...

# %%
# creating a pivot table to show statistics for categories
df.pivot_table(index="Category",values="Followers",aggfunc=["mean","min","max","sum"],sort=False)
# Out:
#                                                mean        min        max  \
#                                           Followers  Followers  Followers
# Category
# Sports with a ball                     3.225825e+07    5400000  400100000
# Fashion|Modeling|Beauty                3.088000e+08  308800000  308800000
# Sports with a ball|Family              1.730500e+08   39800000  306300000
# Modeling|Fashion                       6.622500e+07   11400000  217800000
# Music|Lifestyle                        4.848000e+07    7600000  295800000
# ...                                             ...        ...        ...
# Photography|Lifestyle                  7.900000e+06    7900000    7900000
# Modeling|Music                         6.800000e+06    6800000    6800000
# Beauty|Art|Artists|Modeling            1.360000e+07   13600000   13600000
# Humor|Fun|Happiness|Shows|Art|Artists  1.570000e+07   15700000   15700000
# ...

# %%
# creating a new dataframe for the India
df_India=df[df["Audience Country"]=="India"]
df_India.head()
# Out:
#    Country  Rank       Account              Title  \
# 0      All     1     cristiano  Cristiano Ronaldo
# 14     All    15   virat.kohli        Virat Kohli
# 19     All    20  justinbieber      Justin Bieber
# 27     All    28       therock            therock
# 28     All    29     instagram          Instagram
#
#                                        Link  \
# 0      https://www.instagram.com/cristiano/
# 14   https://www.instagram.com/virat.kohli/
# 19  https://www.instagram.com/justinbieber/
# 27       https://www.instagram.com/therock/
# 28     https://www.instagram.com/instagram/
#
#                                Category  Followers Audience Country  \
# 0                    Sports with a ball  400100000            India
# 14                   Sports with a ball  182600000            India
# 19                                Music  219800000            India
# 27  Cinema|Actors/actresses|Fitness|Gym  295800000            India
# ...

# %%
# turning the floats to ints
df_India = df_India.astype({"Followers":"int", "Authentic engagement":"int", "Engagement avg": "int"})
df_India.head()
# Out:
#    Country  Rank       Account              Title  \
# 0      All     1     cristiano  Cristiano Ronaldo
# 14     All    15   virat.kohli        Virat Kohli
# 19     All    20  justinbieber      Justin Bieber
# 27     All    28       therock            therock
# 28     All    29     instagram          Instagram
#
#                                        Link  \
# 0      https://www.instagram.com/cristiano/
# 14   https://www.instagram.com/virat.kohli/
# 19  https://www.instagram.com/justinbieber/
# 27       https://www.instagram.com/therock/
# 28     https://www.instagram.com/instagram/
#
#                                Category  Followers Audience Country  \
# 0                    Sports with a ball  400100000            India
# 14                   Sports with a ball  182600000            India
# 19                                Music  219800000            India
# 27  Cinema|Actors/actresses|Fitness|Gym  295800000            India
# ...

# %%
# pivot table to show statistics on category followers in the India
df_India.pivot_table(index= 'Category', values= "Followers", aggfunc= ['mean', 'sum','min','max'], sort= False)
# Out:
#                                                            mean         sum  \
#                                                       Followers   Followers
# Category
# Sports with a ball                                 7.271000e+07   727100000
# Music                                              5.219000e+07   521900000
# Cinema|Actors/actresses|Fitness|Gym                2.958000e+08   295800000
# Photography                                        4.696000e+08   469600000
# Beauty                                             6.160000e+07    61600000
# Cinema|Actors/actresses                            2.592143e+07  1451600000
# Finance|Economics|Business|Careers                 6.530000e+07    65300000
# Lifestyle|Fashion|Clothing|Outfits                 3.340000e+07    33400000
# Music|Cinema|Actors/actresses                      2.135000e+07    85400000
# Beauty|Art|Artists|Cinema|Actors/actresses         2.860000e+07    28600000
# ...

# %%
# showing the Category with the most followers
tf=df_India.nlargest(10,"Followers")
tf.pivot_table(index="Category",values="Followers",aggfunc=["sum"], sort=False)
# Out:
#                                            sum
#                                      Followers
# Category
# Photography                          469600000
# Sports with a ball                   582700000
# Cinema|Actors/actresses|Fitness|Gym  295800000
# Music                                291400000
# Cinema|Actors/actresses              142900000
# Science|Photography                   73900000
# Family|Sports with a ball             71100000

# %%
# creating dataframe for top 20 followers
t2f=df_India.nlargest(20,"Followers")
t2f.pivot_table(index="Category",values="Followers",aggfunc=["sum"],sort=False)
# Out:
#                                            sum
#                                      Followers
# Category
# Photography                          469600000
# Sports with a ball                   635000000
# Cinema|Actors/actresses|Fitness|Gym  295800000
# Music                                359000000
# Cinema|Actors/actresses              493800000
# Science|Photography                   73900000
# Family|Sports with a ball             71100000
# Finance|Economics|Business|Careers    65300000
# Beauty                                61600000

# %%
# creating dataframe for top 20 followers
t2f=df_India.nlargest(20,"Followers")
t2f
# Out:
#     Country  Rank          Account                     Title  \
# 28      All    29        instagram                 Instagram
# 0       All     1        cristiano         Cristiano Ronaldo
# 27      All    28          therock                   therock
# 19      All    20     justinbieber             Justin Bieber
# 14      All    15      virat.kohli               Virat Kohli
# 64      All    65   priyankachopra                  Priyanka
# 86      All    87             nasa                      NASA
# 117     All   118          shakira                   Shakira
# 77      All    78     davidbeckham             David Beckham
# 70      All    71   shraddhakapoor                Shraddha ✶
# 109     All   110       nehakakkar  Neha Kakkar (Mrs. Singh)
# 44      All    45     narendramodi             Narendra Modi
# 126     All   127  deepikapadukone          Deepika Padukone
# 35      All    36      katrinakaif              Katrina Kaif
# ...

# %%
# showing the categories with the most avg audience engagement
avgtopeng=df_India.nlargest(20,"Engagement avg")
avgtopeng.pivot_table(index="Category",values="Engagement avg",sort=False)
# Out:
#                                             Engagement avg
# Category
# Sports with a ball                            5.950000e+06
# Music                                         3.900000e+06
# Beauty                                        3.800000e+06
# Music|Cinema|Actors/actresses                 3.600000e+06
# Lifestyle|Fashion|Clothing|Outfits            3.200000e+06
# Beauty|Art|Artists|Cinema|Actors/actresses    2.700000e+06
# Cinema|Actors/actresses                       1.842857e+06
# Finance|Economics|Business|Careers            2.000000e+06
# Fitness|Gym|Lifestyle                         2.000000e+06
# Computers|Gadgets|Machinery|Technologies      1.500000e+06
# Cinema|Actors/actresses|Music                 1.400000e+06
# Sports with a ball|Lifestyle                  1.300000e+06

# %%
# creating a new fashion category dataframe to include all of the subsets
fashion=df_India[df_India["Category"].str.contains("Fashion", na=False)]
fashion.head()
# Out:
#     Country  Rank                Account                Title  \
# 50      All    51            georginagio  Georgina Rodríguez
# 456     All   457  keerthysureshofficial       Keerthy Suresh
# 754     All   755         nita_shilimkar       Nita Shilimkar
# 782     All   783            sonamkapoor   Sonam Kapoor Ahuja
#
#                                                  Link  \
# 50             https://www.instagram.com/georginagio/
# 456  https://www.instagram.com/keerthysureshofficial/
# 754         https://www.instagram.com/nita_shilimkar/
# 782            https://www.instagram.com/sonamkapoor/
#
#                                Category  Followers Audience Country  \
# 50   Lifestyle|Fashion|Clothing|Outfits   33400000            India
# 456     Fashion|Cinema|Actors/actresses   11600000            India
# 754                    Fashion|Modeling    9500000            India
# 782                    Fashion|Modeling   31700000            India
#
# ...

# %%
# plotting followers
plt.figure(figsize=(12,8))
fig1=plt.bar(tf.Category, tf.Followers,)
plt.xticks(fontsize= 12, rotation= 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 10 Categories by Followers", fontsize = 15)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis= "y", style= 'plain')
plt.show()

# %%
# plotting followers
plt.figure(figsize=(12,8))
fig1=plt.bar(t2f.Category, t2f.Followers,)
plt.xticks(fontsize= 12, rotation= 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 20 Categories by Followers", fontsize = 15)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis= "y", style= 'plain')
plt.show()

# %%
# plotting the number of accounts between 0 and 60 million followers
plt.figure(figsize=(12,8))
plt.hist(df_India.Followers, range=(0, 60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the India', fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(style= 'plain')
